# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset[['charges']]

# %%
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','poly','sigmoid','linear'],'C':[10,1000,1000,2000,3000]}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\PC\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 1000, 1000, 2000, 3000],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for the best parameter{'C': 1000, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.137657  6.248474e-03         0.071858    7.652903e-03      10
# 1        0.117304  5.210385e-03         0.022776    7.108475e-03      10
# 2        0.228069  3.061082e-02         0.068733    7.652942e-03      10
# 3        0.246815  1.821719e-02         0.046864    5.091228e-07      10
# 4        0.290554  1.593060e-02         0.134342    7.652923e-03    1000
# 5        0.328044  9.879630e-03         0.043739    6.248617e-03    1000
# 6        0.315547  1.530580e-02         0.068734    7.652962e-03    1000
# 7        1.265315  1.036195e-01         0.028118    1.821724e-02    1000
# 8        0.240566  4.484122e-02         0.103100    3.506993e-02    1000
# 9        0.162460  1.249516e-02         0.024994    7.653974e-03    1000
# 10       0.162460  7.652865e-03         0.046864    9.879780e-03    1000
# 11       1.302809  1.604045e-01         0.043739    6.251764e-03    1000
# 12       0.165586  7.654637e-03         0.071855    7.655493e-03    2000
# 13       0.243691  6.671629e-02         0.037492    7.652631e-03    2000
# 14       0.296798  9.876011e-03         0.068735    7.653741e-03    2000
# 15       2.318182  3.964953e-01         0.024994    7.652748e-03    2000
# 16       0.287423  7.651739e-03         0.128100    6.244973e-03    3000
# 17       0.265560  6.553437e-02         0.021870    7.652514e-03    3000
# 18       0.156211  2.431402e-07         0.040616    7.652826e-03    3000
# 19       2.714969  3.302686e-01         0.015623    2.434206e-06    3000
#
#    param_kernel                            params  split0_test_score  \
# 0           rbf        {'C': 10, 'kernel': 'rbf'}          -0.110409
# 1          poly       {'C': 10, 'kernel': 'poly'}          -0.125153
# 2       sigmoid    {'C': 10, 'kernel': 'sigmoid'}          -0.116743
# 3        linear     {'C': 10, 'kernel': 'linear'}          -0.018943
# 4           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 5          poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 6       sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 7        linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 8           rbf      {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 9          poly     {'C': 1000, 'kernel': 'poly'}          -0.080527
# 10      sigmoid  {'C': 1000, 'kernel': 'sigmoid'}          -2.043140
# 11       linear   {'C': 1000, 'kernel': 'linear'}           0.736398
# 12          rbf      {'C': 2000, 'kernel': 'rbf'}          -0.143510
# 13         poly     {'C': 2000, 'kernel': 'poly'}          -0.020567
# 14      sigmoid  {'C': 2000, 'kernel': 'sigmoid'}          -7.209317
# 15       linear   {'C': 2000, 'kernel': 'linear'}           0.682349
# 16          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 17         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 18      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
# 19       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.097459          -0.074488          -0.099597
# 1           -0.081505          -0.111907          -0.131602
# 2           -0.119312          -0.085214          -0.108210
# 3            0.029886           0.022167           0.003112
# 4           -0.098267          -0.123724          -0.137137
# 5           -0.028469          -0.073376          -0.086611
# 6           -2.686121          -2.194563          -2.210858
# 7            0.675162           0.680002           0.699377
# 8           -0.098267          -0.123724          -0.137137
# 9           -0.028469          -0.073376          -0.086611
# 10          -2.686121          -2.194563          -2.210858
# 11           0.675162           0.680002           0.699377
# 12          -0.087595          -0.113312          -0.128591
# 13           0.035685          -0.011468          -0.024587
# 14          -9.282940          -7.776578          -7.745074
# 15           0.630642           0.750714           0.646368
# 16          -0.075578          -0.100199          -0.116051
# 17           0.098496           0.049291           0.035615
# 18         -20.498908         -17.095474         -16.750877
# 19           0.626814           0.732806           0.633479
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.124428        -0.101276        0.016459               10
# 1           -0.179328        -0.125899        0.031794               13
# 2           -0.108716        -0.107639        0.012029               11
# 3           -0.066653        -0.006086        0.034672                6
# 4           -0.206405        -0.144193        0.036262               15
# 5           -0.134493        -0.080695        0.033795                8
# 6           -1.942521        -2.215441        0.255409               17
# 7            0.677952         0.693778        0.022955                1
# 8           -0.206405        -0.144193        0.036262               15
# 9           -0.134493        -0.080695        0.033795                8
# 10          -1.942521        -2.215441        0.255409               17
# 11           0.677952         0.693778        0.022955                1
# 12          -0.193992        -0.133400        0.035492               14
# 13          -0.076360        -0.019459        0.035693                7
# 14          -6.891719        -7.781126        0.821557               19
# 15           0.722261         0.686467        0.045056                3
# 16          -0.179304        -0.120018        0.034578               12
# 17          -0.020924         0.040035        0.038064                5
# 18         -15.012168       -16.983856        1.914783               20
# 19           0.698692         0.673914        0.039876                4

# %%
age_input=float(input("Age:"))
bmi_input=int(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# Sex Male 0 or 1:0
# Smoker yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_prediction={}".format(Future_Prediction))
# Out:
# Future_prediction=[30603.97369964]
# C:\Users\PC\Anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   "X does not have valid feature names, but"
